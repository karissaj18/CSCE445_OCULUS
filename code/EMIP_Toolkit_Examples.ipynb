# %% [markdown]
# # EMIP Toolkit Examples:
#
# In this file we will show examples of the main functionalities included in the EMIP Toolkit.
#
# This includes:
# •	Reading Raw Data Files from EMIP Dataset into Toolkit Containers.
# •	Applying a Fixation Filter to Raw Data.
# •	Raw Data and Filtered Fixation Visualization.
# •	Apply Fixation Correction Through Offset.
# •	Undo Applied Offset.
# •	Generate AOIs for any EMIP Trial.
# •	Draw AOIs over Trial Image.
# •	Add Text Tokens to Generated AOIs.
# •	Add srcML Tags to AOIs and Tokens.
# •	Hit Test Between Fixations and AOIs.

# %%
import emip_toolkit as tk
import numpy

# %% [markdown]
# # Reading Raw Data Files from EMIP Dataset:
#
# 1. Download the EMIP dataset and data collection matrial from: http://emipws.org/emip_dataset/
# 2. Unzip the dataset and data collection matrial in the parent directry to the directory where this tutorial is.
# 3. The folder structure should look like the following:
#
# -parent_dir
#     + emip_dataset
#             + rawdata
#             + EMIP_DataCollection_Materials
#     + current_directory
#             + EMIP_Toolkit_Examples

# %%
EMIP = tk.EMIP_dataset('../emip_dataset/rawdata/', 216)   # gets the structured data of 10 subjects

print('number of subjects: ', len(EMIP))
print('subject ID: ', EMIP['100'].trial[0].get_subject_id())
print('number of trials: ', EMIP['100'].get_number_of_trials())
print('number of samples in trial: ',EMIP['100'].trial[0].get_sample_number())
# Out:
# parsing file: ../emip_dataset/rawdata/100_rawdata.tsv
# parsing file: ../emip_dataset/rawdata/101_rawdata.tsv
# parsing file: ../emip_dataset/rawdata/102_rawdata.tsv
# parsing file: ../emip_dataset/rawdata/103_rawdata.tsv
# parsing file: ../emip_dataset/rawdata/104_rawdata.tsv
# parsing file: ../emip_dataset/rawdata/105_rawdata.tsv
# parsing file: ../emip_dataset/rawdata/106_rawdata.tsv
# parsing file: ../emip_dataset/rawdata/107_rawdata.tsv
# parsing file: ../emip_dataset/rawdata/108_rawdata.tsv
# parsing file: ../emip_dataset/rawdata/109_rawdata.tsv
# parsing file: ../emip_dataset/rawdata/10_rawdata.tsv
# parsing file: ../emip_dataset/rawdata/110_rawdata.tsv
# parsing file: ../emip_dataset/rawdata/111_rawdata.tsv
# parsing file: ../emip_dataset/rawdata/112_rawdata.tsv
# parsing file: ../emip_dataset/rawdata/113_rawdata.tsv
# parsing file: ../emip_dataset/rawdata/114_rawdata.tsv
# parsing file: ../emip_dataset/rawdata/115_rawdata.tsv
# parsing file: ../emip_dataset/rawdata/116_rawdata.tsv
# parsing file: ../emip_dataset/rawdata/117_rawdata.tsv
# parsing file: ../emip_dataset/rawdata/118_rawdata.tsv
# parsing file: ../emip_dataset/rawdata/119_rawdata.tsv
# parsing file: ../emip_dataset/rawdata/11_rawdata.tsv
# parsing file: ../emip_dataset/rawdata/120_rawdata.tsv
# parsing file: ../emip_dataset/rawdata/121_rawdata.tsv
# parsing file: ../emip_dataset/rawdata/122_rawdata.tsv
# parsing file: ../emip_dataset/rawdata/123_rawdata.tsv
# parsing file: ../emip_dataset/rawdata/124_rawdata.tsv
# parsing file: ../emip_dataset/rawdata/125_rawdata.tsv
# parsing file: ../emip_dataset/rawdata/126_rawdata.tsv
# parsing file: ../emip_dataset/rawdata/127_rawdata.tsv
# parsing file: ../emip_dataset/rawdata/128_rawdata.tsv
# parsing file: ../emip_dataset/rawdata/129_rawdata.tsv
# parsing file: ../emip_dataset/rawdata/12_rawdata.tsv
# parsing file: ../emip_dataset/rawdata/130_rawdata.tsv
# parsing file: ../emip_dataset/rawdata/131_rawdata.tsv
# parsing file: ../emip_dataset/rawdata/132_rawdata.tsv
# parsing file: ../emip_dataset/rawdata/133_rawdata.tsv
# parsing file: ../emip_dataset/rawdata/134_rawdata.tsv
# parsing file: ../emip_dataset/rawdata/135_rawdata.tsv
# parsing file: ../emip_dataset/rawdata/136_rawdata.tsv
# parsing file: ../emip_dataset/rawdata/137_rawdata.tsv
# parsing file: ../emip_dataset/rawdata/138_rawdata.tsv
# parsing file: ../emip_dataset/rawdata/139_rawdata.tsv
# parsing file: ../emip_dataset/rawdata/13_rawdata.tsv
# parsing file: ../emip_dataset/rawdata/140_rawdata.tsv
# parsing file: ../emip_dataset/rawdata/141_rawdata.tsv
# parsing file: ../emip_dataset/rawdata/142_rawdata.tsv
# parsing file: ../emip_dataset/rawdata/143_rawdata.tsv
# parsing file: ../emip_dataset/rawdata/144_rawdata.tsv
# parsing file: ../emip_dataset/rawdata/145_rawdata.tsv
# parsing file: ../emip_dataset/rawdata/146_rawdata.tsv
# parsing file: ../emip_dataset/rawdata/147_rawdata.tsv
# parsing file: ../emip_dataset/rawdata/148_rawdata.tsv
# parsing file: ../emip_dataset/rawdata/149_rawdata.tsv
# parsing file: ../emip_dataset/rawdata/14_rawdata.tsv
# parsing file: ../emip_dataset/rawdata/150_rawdata.tsv
# parsing file: ../emip_dataset/rawdata/151_rawdata.tsv
# parsing file: ../emip_dataset/rawdata/152_rawdata.tsv
# parsing file: ../emip_dataset/rawdata/153_rawdata.tsv
# parsing file: ../emip_dataset/rawdata/154_rawdata.tsv
# parsing file: ../emip_dataset/rawdata/155_rawdata.tsv
# parsing file: ../emip_dataset/rawdata/156_rawdata.tsv
# parsing file: ../emip_dataset/rawdata/157_rawdata.tsv
# parsing file: ../emip_dataset/rawdata/158_rawdata.tsv
# parsing file: ../emip_dataset/rawdata/159_rawdata.tsv
# parsing file: ../emip_dataset/rawdata/15_rawdata.tsv
# parsing file: ../emip_dataset/rawdata/160_rawdata.tsv
# parsing file: ../emip_dataset/rawdata/161_rawdata.tsv
# parsing file: ../emip_dataset/rawdata/162_rawdata.tsv
# parsing file: ../emip_dataset/rawdata/163_rawdata.tsv
# parsing file: ../emip_dataset/rawdata/164_rawdata.tsv
# parsing file: ../emip_dataset/rawdata/165_rawdata.tsv
# parsing file: ../emip_dataset/rawdata/166_rawdata.tsv
# parsing file: ../emip_dataset/rawdata/167_rawdata.tsv
# parsing file: ../emip_dataset/rawdata/168_rawdata.tsv
# parsing file: ../emip_dataset/rawdata/169_rawdata.tsv
# parsing file: ../emip_dataset/rawdata/16_rawdata.tsv
# parsing file: ../emip_dataset/rawdata/170_rawdata.tsv
# parsing file: ../emip_dataset/rawdata/171_rawdata.tsv
# parsing file: ../emip_dataset/rawdata/172_rawdata.tsv
# parsing file: ../emip_dataset/rawdata/173_rawdata.tsv
# parsing file: ../emip_dataset/rawdata/174_rawdata.tsv
# parsing file: ../emip_dataset/rawdata/175_rawdata.tsv
# parsing file: ../emip_dataset/rawdata/176_rawdata.tsv
# parsing file: ../emip_dataset/rawdata/177_rawdata.tsv
# parsing file: ../emip_dataset/rawdata/178_rawdata.tsv
# parsing file: ../emip_dataset/rawdata/179_rawdata.tsv
# parsing file: ../emip_dataset/rawdata/17_rawdata.tsv
# parsing file: ../emip_dataset/rawdata/180_rawdata.tsv
# parsing file: ../emip_dataset/rawdata/181_rawdata.tsv
# parsing file: ../emip_dataset/rawdata/182_rawdata.tsv
# parsing file: ../emip_dataset/rawdata/183_rawdata.tsv
# parsing file: ../emip_dataset/rawdata/184_rawdata.tsv
# parsing file: ../emip_dataset/rawdata/185_rawdata.tsv
# parsing file: ../emip_dataset/rawdata/186_rawdata.tsv
# parsing file: ../emip_dataset/rawdata/187_rawdata.tsv
# parsing file: ../emip_dataset/rawdata/188_rawdata.tsv
# parsing file: ../emip_dataset/rawdata/189_rawdata.tsv
# parsing file: ../emip_dataset/rawdata/18_rawdata.tsv
# parsing file: ../emip_dataset/rawdata/190_rawdata.tsv
# parsing file: ../emip_dataset/rawdata/191_rawdata.tsv
# parsing file: ../emip_dataset/rawdata/192_rawdata.tsv
# parsing file: ../emip_dataset/rawdata/193_rawdata.tsv
# parsing file: ../emip_dataset/rawdata/194_rawdata.tsv
# parsing file: ../emip_dataset/rawdata/195_rawdata.tsv
# parsing file: ../emip_dataset/rawdata/196_rawdata.tsv
# parsing file: ../emip_dataset/rawdata/197_rawdata.tsv
# parsing file: ../emip_dataset/rawdata/198_rawdata.tsv
# parsing file: ../emip_dataset/rawdata/199_rawdata.tsv
# parsing file: ../emip_dataset/rawdata/19_rawdata.tsv
# parsing file: ../emip_dataset/rawdata/1_rawdata.tsv
# parsing file: ../emip_dataset/rawdata/200_rawdata.tsv
# parsing file: ../emip_dataset/rawdata/201_rawdata.tsv
# parsing file: ../emip_dataset/rawdata/202_rawdata.tsv
# parsing file: ../emip_dataset/rawdata/203_rawdata.tsv
# parsing file: ../emip_dataset/rawdata/204_rawdata.tsv
# parsing file: ../emip_dataset/rawdata/205_rawdata.tsv
# parsing file: ../emip_dataset/rawdata/206_rawdata.tsv
# parsing file: ../emip_dataset/rawdata/207_rawdata.tsv
# parsing file: ../emip_dataset/rawdata/208_rawdata.tsv
# parsing file: ../emip_dataset/rawdata/209_rawdata.tsv
# parsing file: ../emip_dataset/rawdata/20_rawdata.tsv
# parsing file: ../emip_dataset/rawdata/210_rawdata.tsv
# parsing file: ../emip_dataset/rawdata/211_rawdata.tsv
# parsing file: ../emip_dataset/rawdata/212_rawdata.tsv
# parsing file: ../emip_dataset/rawdata/213_rawdata.tsv
# parsing file: ../emip_dataset/rawdata/214_rawdata.tsv
# parsing file: ../emip_dataset/rawdata/215_rawdata.tsv
# parsing file: ../emip_dataset/rawdata/216_rawdata.tsv
# parsing file: ../emip_dataset/rawdata/21_rawdata.tsv
# parsing file: ../emip_dataset/rawdata/22_rawdata.tsv
# parsing file: ../emip_dataset/rawdata/23_rawdata.tsv
# parsing file: ../emip_dataset/rawdata/24_rawdata.tsv
# parsing file: ../emip_dataset/rawdata/25_rawdata.tsv
# parsing file: ../emip_dataset/rawdata/26_rawdata.tsv
# parsing file: ../emip_dataset/rawdata/27_rawdata.tsv
# parsing file: ../emip_dataset/rawdata/28_rawdata.tsv
# parsing file: ../emip_dataset/rawdata/29_rawdata.tsv
# parsing file: ../emip_dataset/rawdata/2_rawdata.tsv
# parsing file: ../emip_dataset/rawdata/30_rawdata.tsv
# parsing file: ../emip_dataset/rawdata/31_rawdata.tsv
# parsing file: ../emip_dataset/rawdata/32_rawdata.tsv
# parsing file: ../emip_dataset/rawdata/33_rawdata.tsv
# parsing file: ../emip_dataset/rawdata/34_rawdata.tsv
# parsing file: ../emip_dataset/rawdata/35_rawdata.tsv
# parsing file: ../emip_dataset/rawdata/36_rawdata.tsv
# parsing file: ../emip_dataset/rawdata/37_rawdata.tsv
# parsing file: ../emip_dataset/rawdata/38_rawdata.tsv
# parsing file: ../emip_dataset/rawdata/39_rawdata.tsv
# parsing file: ../emip_dataset/rawdata/3_rawdata.tsv
# parsing file: ../emip_dataset/rawdata/40_rawdata.tsv
# parsing file: ../emip_dataset/rawdata/41_rawdata.tsv
# parsing file: ../emip_dataset/rawdata/42_rawdata.tsv
# parsing file: ../emip_dataset/rawdata/43_rawdata.tsv
# parsing file: ../emip_dataset/rawdata/44_rawdata.tsv
# parsing file: ../emip_dataset/rawdata/45_rawdata.tsv
# parsing file: ../emip_dataset/rawdata/46_rawdata.tsv
# parsing file: ../emip_dataset/rawdata/47_rawdata.tsv
# parsing file: ../emip_dataset/rawdata/48_rawdata.tsv
# parsing file: ../emip_dataset/rawdata/49_rawdata.tsv
# parsing file: ../emip_dataset/rawdata/4_rawdata.tsv
# parsing file: ../emip_dataset/rawdata/50_rawdata.tsv
# parsing file: ../emip_dataset/rawdata/51_rawdata.tsv
# parsing file: ../emip_dataset/rawdata/52_rawdata.tsv
# parsing file: ../emip_dataset/rawdata/53_rawdata.tsv
# parsing file: ../emip_dataset/rawdata/54_rawdata.tsv
# parsing file: ../emip_dataset/rawdata/55_rawdata.tsv
# parsing file: ../emip_dataset/rawdata/56_rawdata.tsv
# parsing file: ../emip_dataset/rawdata/57_rawdata.tsv
# parsing file: ../emip_dataset/rawdata/58_rawdata.tsv
# parsing file: ../emip_dataset/rawdata/59_rawdata.tsv
# parsing file: ../emip_dataset/rawdata/5_rawdata.tsv
# parsing file: ../emip_dataset/rawdata/60_rawdata.tsv
# parsing file: ../emip_dataset/rawdata/61_rawdata.tsv
# parsing file: ../emip_dataset/rawdata/62_rawdata.tsv
# parsing file: ../emip_dataset/rawdata/63_rawdata.tsv
# parsing file: ../emip_dataset/rawdata/64_rawdata.tsv
# parsing file: ../emip_dataset/rawdata/65_rawdata.tsv
# parsing file: ../emip_dataset/rawdata/66_rawdata.tsv
# parsing file: ../emip_dataset/rawdata/67_rawdata.tsv
# parsing file: ../emip_dataset/rawdata/68_rawdata.tsv
# parsing file: ../emip_dataset/rawdata/69_rawdata.tsv
# parsing file: ../emip_dataset/rawdata/6_rawdata.tsv
# parsing file: ../emip_dataset/rawdata/70_rawdata.tsv
# parsing file: ../emip_dataset/rawdata/71_rawdata.tsv
# parsing file: ../emip_dataset/rawdata/72_rawdata.tsv
# parsing file: ../emip_dataset/rawdata/73_rawdata.tsv
# parsing file: ../emip_dataset/rawdata/74_rawdata.tsv
# parsing file: ../emip_dataset/rawdata/75_rawdata.tsv
# parsing file: ../emip_dataset/rawdata/76_rawdata.tsv
# parsing file: ../emip_dataset/rawdata/77_rawdata.tsv
# parsing file: ../emip_dataset/rawdata/78_rawdata.tsv
# parsing file: ../emip_dataset/rawdata/79_rawdata.tsv
# parsing file: ../emip_dataset/rawdata/7_rawdata.tsv
# parsing file: ../emip_dataset/rawdata/80_rawdata.tsv
# parsing file: ../emip_dataset/rawdata/81_rawdata.tsv
# parsing file: ../emip_dataset/rawdata/82_rawdata.tsv
# parsing file: ../emip_dataset/rawdata/83_rawdata.tsv
# parsing file: ../emip_dataset/rawdata/84_rawdata.tsv
# parsing file: ../emip_dataset/rawdata/85_rawdata.tsv
# parsing file: ../emip_dataset/rawdata/86_rawdata.tsv
# parsing file: ../emip_dataset/rawdata/87_rawdata.tsv
# parsing file: ../emip_dataset/rawdata/88_rawdata.tsv
# parsing file: ../emip_dataset/rawdata/89_rawdata.tsv
# parsing file: ../emip_dataset/rawdata/8_rawdata.tsv
# parsing file: ../emip_dataset/rawdata/90_rawdata.tsv
# parsing file: ../emip_dataset/rawdata/91_rawdata.tsv
# parsing file: ../emip_dataset/rawdata/92_rawdata.tsv
# parsing file: ../emip_dataset/rawdata/93_rawdata.tsv
# parsing file: ../emip_dataset/rawdata/94_rawdata.tsv
# parsing file: ../emip_dataset/rawdata/95_rawdata.tsv
# parsing file: ../emip_dataset/rawdata/96_rawdata.tsv
# parsing file: ../emip_dataset/rawdata/97_rawdata.tsv
# parsing file: ../emip_dataset/rawdata/98_rawdata.tsv
# parsing file: ../emip_dataset/rawdata/99_rawdata.tsv
# parsing file: ../emip_dataset/rawdata/9_rawdata.tsv
# number of subjects:  216
# subject ID:  100
# number of trials:  7
# number of samples in trial:  12040

# %% [markdown]
# # Applying a Fixation Filter to Raw Data:
#
# EMIP Toolkit implements a dispersion-based fixation detection algorithm (I-DT). The technique uses a duration window over the gaze data with a length equal to the minimum fixation duration threshold. In addition to this time window, samples are added until sample spacial dispersion exceeds the maximum dispersion threshold.
#
# The fixation filter parameters have default values of:
# * minimum_duration 50 milliseconds
# * sample_duration 4 milliseconds
# * maxmimum_dispersion 25 pixels

# %%
# select any subject and trial number.
subject_ID = '160'
trial_num = 2      # valid source code trials are 2 and 5

# apply fixation filter to specific trial
# EMIP[subject_ID].trial[trial_num].filter_fixations(minimum_duration=50, sample_duration=4, maxmimum_dispersion=25)

# you can use the method get_fixation_number() to count the fixations after filtering in a trial
print("number of fixations: ", EMIP[subject_ID].trial[trial_num].get_fixation_number())
# Out:
# number of fixations:  639

# %%
# accessor for samples count
print("raw sample count:", EMIP[subject_ID].trial[trial_num].get_sample_number())

# accessor for trial image
print("trial image:", EMIP[subject_ID].trial[trial_num].get_trial_image())
# Out:
# raw sample count: 22962
# trial image: vehicle_java.jpg

# %% [markdown]
# # Raw Data and Filtered Fixation visualization:
#
# You can visualize any trial raw data, filtered fixations, or a combination of the two.  Filtered fixations are in green, and raw samples are in red.
#
# Try changing the code to:
#
# ```
# draw_trial(image_path, False, True)
# ```
# or
# ```
# draw_trial(image_path, True, False)
# ```

# %%
image_path = "../emip_dataset/stimuli/"

EMIP[subject_ID].trial[trial_num].draw_trial(image_path, draw_raw_data=True, draw_fixation=True)

# %% [markdown]
# # Apply fixation correction through offset:
#
# You can apply fixation corection using sample_offset(x_offset, y_offset) on the Trial object.
#
# Try running this with:
#
# ```
# sample_offset(-200, 100)
# ```
# You can then visualize the trial to see the effect:
# ```
# draw_trial(image_path, True, True)
# ```

# %%
# apply offset
EMIP[subject_ID].trial[trial_num].sample_offset(-200, 100) # x:100 and y:50 just for example

# draw trial again
EMIP[subject_ID].trial[trial_num].draw_trial(image_path, True, True)

# %% [markdown]
# You can get the total applied offset, useful after a few calls to sample_offset method.
#
# Try running this with:
# ```
# get_offset()
# ```

# %%
print("Current offset:", EMIP[subject_ID].trial[trial_num].get_offset())
# Out:
# Current offset: (np.int64(-200), np.int64(100))

# %% [markdown]
# After applying offset to samples you can call fixation filter again to generate fixations from samples at thier new position.

# %% [markdown]
# # Undo applied offset:

# %%
# undo all previous offset
EMIP[subject_ID].trial[trial_num].reset_offset()

# draw trial again
EMIP[subject_ID].trial[trial_num].draw_trial(image_path, draw_raw_data=True, draw_fixation=True)

# %% [markdown]
# # Generate AOIs for any EMIP Trial:
#
# You can generate token level or line level AOIs for any trial code file in the EMIP dataset.
#
# Try running this with:
# ```
# image_path = "emip_dataset/stimuli/"
# image = "rectangle_java2.jpg"
#
# aoi = tk.find_aoi(image, image_path, "sub-line")
# ```

# %%
image_path = "../emip_dataset/stimuli/"
image = "rectangle_java2.jpg"
aoi = tk.find_aoi(image, image_path, level="sub-line")
aoi.head()
# Out:
# C:\Users\karis\Desktop\classes\Spring2025\EMIP-Toolkit- replication package\EMIP-Toolkit- replication package\EMIP Toolkit\emip_toolkit.py:1255: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   aoi = pd.concat([aoi, pd.DataFrame([dic])], ignore_index=True)
#        kind           name      x    y width height                image
# 0  sub-line  line 1 part 1  589.5  222    63     21  rectangle_java2.jpg
# 1  sub-line  line 1 part 2  657.5  222    52     21  rectangle_java2.jpg
# 2  sub-line  line 1 part 3  715.5  222    90     21  rectangle_java2.jpg
# 3  sub-line  line 1 part 4  813.5  222    10     21  rectangle_java2.jpg
# 4  sub-line  line 2 part 1  669.5  259    72     21  rectangle_java2.jpg

# %% [markdown]
# # Draw AOIs over trial image:
#
#
# You can draw the obtained AOIs for the trial code file on the trial image in the EMIP dataset.
#
# Try running this with: <br>
# ```
# image_path = "emip_dataset/stimuli/"
# image = "rectangle_java2.jpg"
#
# tk.draw_aoi(aoi, image, image_path)
# ```

# %%
image = "rectangle_java2.jpg"

tk.draw_aoi(aoi, image, image_path)
# Out:
# <PIL.Image.Image image mode=1 size=1920x1080>

# %% [markdown]
# # Add text tokens to generated AOIs:

# %%
aoi.head()
# Out:
#        kind           name      x    y width height                image
# 0  sub-line  line 1 part 1  589.5  222    63     21  rectangle_java2.jpg
# 1  sub-line  line 1 part 2  657.5  222    52     21  rectangle_java2.jpg
# 2  sub-line  line 1 part 3  715.5  222    90     21  rectangle_java2.jpg
# 3  sub-line  line 1 part 4  813.5  222    10     21  rectangle_java2.jpg
# 4  sub-line  line 2 part 1  669.5  259    72     21  rectangle_java2.jpg

# %%
file_path = "../emip_dataset/EMIP_DataCollection_Materials/emip_stimulus_programs/"

aois_with_tokens = tk.add_tokens_to_AOIs(file_path, aoi)

aois_with_tokens
# Out:
#          kind            name       x    y width height                image  \
# 0    sub-line   line 1 part 1   589.5  222    63     21  rectangle_java2.jpg
# 1    sub-line   line 1 part 2   657.5  222    52     21  rectangle_java2.jpg
# 2    sub-line   line 1 part 3   715.5  222    90     21  rectangle_java2.jpg
# 3    sub-line   line 1 part 4   813.5  222    10     21  rectangle_java2.jpg
# 4    sub-line   line 2 part 1   669.5  259    72     21  rectangle_java2.jpg
# ..        ...             ...     ...  ...   ...    ...                  ...
# 139  sub-line  line 16 part 5  1057.5  766    10     21  rectangle_java2.jpg
# 140  sub-line  line 16 part 6  1077.5  766     9     21  rectangle_java2.jpg
# 141  sub-line  line 16 part 7  1096.5  766    10     21  rectangle_java2.jpg
# 142  sub-line  line 17 part 1   672.5  804    10     18  rectangle_java2.jpg
# 143  sub-line  line 18 part 1   612.5  841    10     18  rectangle_java2.jpg
#
#          token
# 0       public
# 1        class
# 2    Rectangle
# 3            {
# 4      private
# ..         ...
# 139          )
# 140          )
# 141          ;
# 142          }
# 143          }
#
# [144 rows x 8 columns]

# %% [markdown]
# # Add srcML tags to AOIs and tokens:
#
# The srcML format is an XML representation for source code, where the markup tags identify elements of the abstract syntax for the language. Read more about it: https://www.srcml.org/about.html

# %%
srcML_path = "./datasets/EMIP2021/"

aois_tokens_srcml = tk.add_srcml_to_AOIs(aois_with_tokens, srcML_path)

aois_tokens_srcml
# Out:
#          kind            name       x    y width height                image  \
# 0    sub-line   line 1 part 1   589.5  222    63     21  rectangle_java2.jpg
# 1    sub-line   line 1 part 2   657.5  222    52     21  rectangle_java2.jpg
# 2    sub-line   line 1 part 3   715.5  222    90     21  rectangle_java2.jpg
# 3    sub-line   line 1 part 4   813.5  222    10     21  rectangle_java2.jpg
# 4    sub-line   line 2 part 1   669.5  259    72     21  rectangle_java2.jpg
# ..        ...             ...     ...  ...   ...    ...                  ...
# 139  sub-line  line 16 part 5  1057.5  766    10     21  rectangle_java2.jpg
# 140  sub-line  line 16 part 6  1077.5  766     9     21  rectangle_java2.jpg
# 141  sub-line  line 16 part 7  1096.5  766    10     21  rectangle_java2.jpg
# 142  sub-line  line 17 part 1   672.5  804    10     18  rectangle_java2.jpg
# 143  sub-line  line 18 part 1   612.5  841    10     18  rectangle_java2.jpg
#
#          token                                          srcML_tag
# 0       public                                   class->specifier
# 1        class                                              class
# 2    Rectangle                                        class->name
# 3            {                                       class->block
# 4      private     class->block->decl_stmt->decl->type->specifier
# ..         ...                                                ...
# 139          )  class->block->function->block->block_content->...
# 140          )  class->block->function->block->block_content->...
# 141          ;  class->block->function->block->block_content->...
# 142          }                      class->block->function->block
# 143          }                                       class->block
#
# [144 rows x 9 columns]

# %% [markdown]
# # Hit Test between Fixations and AOIs:
#
# Match fixations to AOIs to calculate the fixation duration over each AOI (can be customized for line or code token).
# radius is 25 pixels by default and it represents the area around the AOI included in the AOI region.

# %%
aoi_fixes = tk.hit_test(EMIP[subject_ID].trial[trial_num], aois_tokens_srcml, radius=25)

aoi_fixes.head()

aoi_fixes.to_csv('nonnative/p160_t2_fixations.csv', index=False)
aoi_fixes.to_csv('nonnative_low/nl_p160_t2_fixations.csv', index=False)
# Out:
# all fixations: 639
# C:\Users\karis\Desktop\classes\Spring2025\EMIP-Toolkit- replication package\EMIP-Toolkit- replication package\EMIP Toolkit\emip_toolkit.py:1555: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   result = pd.concat([result, df], ignore_index=True)
